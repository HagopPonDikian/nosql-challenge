), 'BusinessType': 'Retailers - supermarkets/hypermarkets', 'BusinessTypeID': 7840}
# {'_id': ObjectId('6529d869eddd243f7f53d86d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d86e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d86f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d870'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f53d871'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d873'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f53d874'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d875'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d876'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d877'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d878'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d879'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d87a'), 'BusinessType': 'Hotel/bed & breakfast/guest house', 'BusinessTypeID': 7842}
# {'_id': ObjectId('6529d869eddd243f7f53d87b'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f53d87c'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f53d87d'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f53d87e'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f53d87f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d880'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f53d881'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f53d882'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f53d883'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f53d887'), 'BusinessType': 'Hotel/bed & breakfast/guest house', 'BusinessTypeID': 7842}
# {'_id': ObjectId('6529d869eddd243f7f53d889'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f53d88a'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f53d88b'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f53d88c'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d88d'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f53d88f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d890'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d891'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f53d892'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d893'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d894'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d895'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d896'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d897'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d898'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f53d899'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f53d89a'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f53d89b'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d89c'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f53d89d'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f53d89e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d89f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d8a0'), 'BusinessType': 'Hotel/bed & breakfast/guest house', 'BusinessTypeID': 7842}
# {'_id': ObjectId('6529d869eddd243f7f53d8a1'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f53d8a2'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d8a3'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d8a4'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f53d8a5'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f53d8a6'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f53d8a7'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f53d8a8'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f53d8a9'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f53d8aa'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f53d8ab'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f53d8ac'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d8ad'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f53d8ae'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d8af'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d8b0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d8b1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f53d8b2'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f53d8b3'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# ...
# {'_id': ObjectId('6529d869eddd243f7f542da7'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f542da8'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f542da9'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# {'_id': ObjectId('6529d869eddd243f7f542daa'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542dab'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dac'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f542dad'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dae'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f542daf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542db0'), 'BusinessType': 'Mobile caterer', 'BusinessTypeID': 7846}
# {'_id': ObjectId('6529d869eddd243f7f542db1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542db2'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542db3'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542db4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542db5'), 'BusinessType': 'Mobile caterer', 'BusinessTypeID': 7846}
# {'_id': ObjectId('6529d869eddd243f7f542db6'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542db7'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# {'_id': ObjectId('6529d869eddd243f7f542db8'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f542db9'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# {'_id': ObjectId('6529d869eddd243f7f542dba'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f542dbb'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# {'_id': ObjectId('6529d869eddd243f7f542dbc'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dbd'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f542dbe'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542dbf'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542dc0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dc1'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542dc2'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542dc3'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# {'_id': ObjectId('6529d869eddd243f7f542dc4'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542dc5'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542dc6'), 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841}
# {'_id': ObjectId('6529d869eddd243f7f542dc7'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542dc8'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f542dc9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dca'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542dcb'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542dcc'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# {'_id': ObjectId('6529d869eddd243f7f542dcd'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542dce'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dcf'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dd0'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542dd1'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f542dd2'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542dd3'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542dd4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dd5'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542dd6'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542dd7'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542dd8'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dd9'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dda'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542ddb'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# {'_id': ObjectId('6529d869eddd243f7f542ddc'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542ddd'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dde'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542ddf'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f542de0'), 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841}
# {'_id': ObjectId('6529d869eddd243f7f542de1'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542de2'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542de3'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f542de4'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f542de5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542de6'), 'BusinessType': 'Manufacturers/packers', 'BusinessTypeID': 7839}
# {'_id': ObjectId('6529d869eddd243f7f542de7'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542de8'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542de9'), 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841}
# {'_id': ObjectId('6529d869eddd243f7f542dea'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f542deb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dec'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542ded'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542dee'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# {'_id': ObjectId('6529d869eddd243f7f542def'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542df0'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542df1'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542df2'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f542df3'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f542df4'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542df5'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542df6'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542df7'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542df8'), 'BusinessType': 'Hotel/bed & breakfast/guest house', 'BusinessTypeID': 7842}
# {'_id': ObjectId('6529d869eddd243f7f542df9'), 'BusinessType': 'Hotel/bed & breakfast/guest house', 'BusinessTypeID': 7842}
# {'_id': ObjectId('6529d869eddd243f7f542dfa'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542dfb'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542dfc'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f542dfd'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542dfe'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542dff'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e00'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e01'), 'BusinessType': 'Distributors/Transporters', 'BusinessTypeID': 7}
# {'_id': ObjectId('6529d869eddd243f7f542e02'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e03'), 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841}
# {'_id': ObjectId('6529d869eddd243f7f542e04'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f542e05'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542e06'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f542e07'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542e08'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e09'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f542e0a'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# {'_id': ObjectId('6529d869eddd243f7f542e0b'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542e0c'), 'BusinessType': 'Mobile caterer', 'BusinessTypeID': 7846}
# {'_id': ObjectId('6529d869eddd243f7f542e0d'), 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841}
# {'_id': ObjectId('6529d869eddd243f7f542e0e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e0f'), 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841}
# {'_id': ObjectId('6529d869eddd243f7f542e10'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e11'), 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5}
# {'_id': ObjectId('6529d869eddd243f7f542e12'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542e13'), 'BusinessType': 'Retailers - supermarkets/hypermarkets', 'BusinessTypeID': 7840}
# {'_id': ObjectId('6529d869eddd243f7f542e14'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f542e15'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e16'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542e17'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e18'), 'BusinessType': 'Retailers - supermarkets/hypermarkets', 'BusinessTypeID': 7840}
# {'_id': ObjectId('6529d869eddd243f7f542e19'), 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841}
# {'_id': ObjectId('6529d869eddd243f7f542e1a'), 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841}
# {'_id': ObjectId('6529d869eddd243f7f542e1b'), 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841}
# {'_id': ObjectId('6529d869eddd243f7f542e1c'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542e1d'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542e1e'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# {'_id': ObjectId('6529d869eddd243f7f542e1f'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e20'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e21'), 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841}
# {'_id': ObjectId('6529d869eddd243f7f542e22'), 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841}
# {'_id': ObjectId('6529d869eddd243f7f542e23'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e24'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542e25'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542e26'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542e27'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542e28'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542e29'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e2a'), 'BusinessType': 'Retailers - other', 'BusinessTypeID': 4613}
# {'_id': ObjectId('6529d869eddd243f7f542e2b'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# {'_id': ObjectId('6529d869eddd243f7f542e2c'), 'BusinessType': 'Takeaway/sandwich shop', 'BusinessTypeID': 7844}
# {'_id': ObjectId('6529d869eddd243f7f542e2d'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e2e'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e2f'), 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841}
# {'_id': ObjectId('6529d869eddd243f7f542e30'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e31'), 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843}
# {'_id': ObjectId('6529d869eddd243f7f542e32'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# {'_id': ObjectId('6529d869eddd243f7f542e33'), 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}
# {'_id': ObjectId('6529d869eddd243f7f542e34'), 'BusinessType': 'Distributors/Transporters', 'BusinessTypeID': 7}
# {'_id': ObjectId('6529d869eddd243f7f542e35'), 'BusinessType': 'School/college/university', 'BusinessTypeID': 7845}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
query = {"BusinessName": "Penang Flavours"}
update = {"$set": {"BusinessTypeID": "1"}}
result = establishments.update_one(query, update)

# %%
# Confirm that the new restaurant was updated
query = {"BusinessName": "Penang Flavours"}
results = establishments.find(query)
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('6529e72b148342b7fe4664d4'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '1', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.08384, 'latitude': 51.490142}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True, 'RatingValue': None}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {"LocalAuthorityName": "Dover"}

counts = establishments.count_documents(query)
counts
# Out:
# 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
query = {"LocalAuthorityName": "Dover"}
dover_del = establishments.delete_many(query)
dover_del

# %%
# Check if any remaining documents include Dover
query = {"LocalAuthorityName": "Dover"}

counts = establishments.count_documents(query)
counts
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('6529d869eddd243f7f53d6d4'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude

# Use the $toInt operator to convert the latitude values to integers
query = {}
update = [
    {
        "$set": {
            "geocode.latitude": {"$toDouble": "$geocode.latitude"},
            "geocode.longitude": {"$toDouble": "$geocode.longitude"}
        }
    }
]
# Update all the documents in the collection that match the filter
result = establishments.update_many(query, update)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
query = {}
update = [{
        "$set": {
            "RatingValue": {"$toInt": "$RatingValue"}
        }}]
result = establishments.update_many(query, update)
result

# %%
# Check that the coordinates and rating value are now numbers
# sample = establishments.find_one()

# longitude_check = type(sample.get("geocode.latitude"))
# latitude_check = type(sample.get("geocode.latitude"))
# rating_value_check = type(sample.get("RatingValue"))
# print(longitude_check)
# print(latitude_check)
# print(rating_value_check)
establishments.find_one()
# Out:
# {'_id': ObjectId('6529d869eddd243f7f53d6d4'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}]}

# %%
# mongo.drop_database('uk_food')
mongo.list_database_names()
# Out:
# ['admin', 'breast_cancer_db', 'config', 'local', 'test', 'ufo_db', 'uk_food']
